# %% [markdown]
# WeatherPy
#
# Analysis
#
#
# Temperature increases as the latitude approaches the equator.
#
#
# Humidity is more concentrated at values where the latitude approaches the equator .
#
#
# Wind speeds increase as the latitude goes away from the equator.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time


# Dependencies
import json
import requests
import random
from citipy import citipy

import seaborn as sns

# Import Open Weather Map API key.
from api_keys import api_key
# Import API key


# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /Users/SLayachi/.local/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/SLayachi/.local/lib/python3.7/site-packages (from citipy) (0.16)
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.
# You are using pip version 10.0.1, however version 19.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# ## Generate Cities List

# %%
lat_values = np.arange(-90, 90, 0.01)
lng_values = np.arange(-180, 180, 0.01)

# %%
# Create an empty data frame to city and weather data
column_names = ('city_name', 'country_code', 'Latitude', 'Longitude','Temp (F)',
            'Humidity (%)','Cloudiness (%)','Wind Speed (mph)')
cities_df = pd.DataFrame(columns = column_names)
cities_df
# Out:
# Empty DataFrame
# Columns: [city_name, country_code, Latitude, Longitude, Temp (F), Humidity (%), Cloudiness (%), Wind Speed (mph)]
# Index: []

# %%
target_url = 'http://api.openweathermap.org/data/2.5/weather?q='
units = 'imperial'

count = 0

# Loop through and grab the Temp, Humidity, Cloudiness and Wind Speed using OpenWeatherMapAPI
    
while len(cities_df) <500:
  
    rand_lat = random.choice(lat_values)
    rand_lng = random.choice(lng_values)
  
    city = citipy.nearest_city(rand_lat, rand_lng)
    city_name = city.city_name
    country_code = city.country_code
    
    
    url = target_url + city_name + ',' + country_code + '&units=' + units + '&APPID=' + api_key
    weather_response = requests.get(url)
    weather_json = weather_response.json()
    if weather_json["cod"] == 200:
        print('City: %s. %s' % (weather_json['name'], url))
        latitude = weather_json["coord"]["lat"]
        longitude = weather_json["coord"]["lon"]
        temperature = weather_json["main"]["temp"]
        humidity = weather_json["main"]["humidity"]
        cloudiness = weather_json["clouds"]["all"]
        windspeed = weather_json["wind"]["speed"]
       
        if city_name not in cities_df.city_name.values:
            print('Status code: %s. DF length is now: %d' % (str(weather_json["cod"]), len(cities_df)+1))
            
            cities_df.set_value(count, "city_name", city_name)
            cities_df.set_value(count, "country_code", country_code)
            cities_df.set_value(count, "Latitude", latitude)
            cities_df.set_value(count, "Longitude", longitude)
            cities_df.set_value(count, "Humidity (%)", humidity)
            cities_df.set_value(count, "Cloudiness (%)", cloudiness)
            cities_df.set_value(count, "Wind Speed (mph)", windspeed)
            cities_df.set_value(count, "Temp (F)", temperature)
            cities_df.set_value(count, "Humidity (%)", humidity)
            cities_df.set_value(count, "Cloudiness (%)", cloudiness)
            cities_df.set_value(count, "Wind Speed (mph)", windspeed)

            count += 1
        else:
            pass
    else:
        pass
    
cities_df.head()
# Out:
# City: Hilo. http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 1
# City: Faanui. http://api.openweathermap.org/data/2.5/weather?q=faanui,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 2
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:37: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:41: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:42: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:43: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:44: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /Users/SLayachi/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:45: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# City: Chuy. http://api.openweathermap.org/data/2.5/weather?q=chuy,uy&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 3
# City: Provideniya. http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 4
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 5
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 6
# City: New Norfolk. http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 7
# City: Hanzhong. http://api.openweathermap.org/data/2.5/weather?q=hanzhong,cn&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 8
# City: Praia. http://api.openweathermap.org/data/2.5/weather?q=praia,cv&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 9
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 10
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 11
# City: Kavieng. http://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 12
# City: Cape Town. http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 13
# City: Fuyang. http://api.openweathermap.org/data/2.5/weather?q=fuyang,cn&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 14
# City: Mnogovershinnyy. http://api.openweathermap.org/data/2.5/weather?q=mnogovershinnyy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 15
# City: Ikwiriri. http://api.openweathermap.org/data/2.5/weather?q=ikwiriri,tz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 16
# City: Wajima. http://api.openweathermap.org/data/2.5/weather?q=wajima,jp&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 17
# City: Cidreira. http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 18
# City: Sarangani. http://api.openweathermap.org/data/2.5/weather?q=sarangani,ph&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 19
# City: Ponta do Sol. http://api.openweathermap.org/data/2.5/weather?q=ponta do sol,cv&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 20
# City: Jamestown. http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 21
# City: Jamestown. http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Luanda. http://api.openweathermap.org/data/2.5/weather?q=luanda,ao&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 22
# City: Paamiut. http://api.openweathermap.org/data/2.5/weather?q=paamiut,gl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 23
# City: Sangar. http://api.openweathermap.org/data/2.5/weather?q=sangar,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 24
# City: Hithadhoo. http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 25
# City: Tura. http://api.openweathermap.org/data/2.5/weather?q=tura,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 26
# City: Stawell. http://api.openweathermap.org/data/2.5/weather?q=stawell,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 27
# City: Busselton. http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 28
# City: Rabo de Peixe. http://api.openweathermap.org/data/2.5/weather?q=rabo de peixe,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 29
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Belgrade. http://api.openweathermap.org/data/2.5/weather?q=belgrade,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 30
# City: Ixtapa. http://api.openweathermap.org/data/2.5/weather?q=ixtapa,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 31
# City: Busselton. http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Hardy. http://api.openweathermap.org/data/2.5/weather?q=port hardy,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 32
# City: San Felipe. http://api.openweathermap.org/data/2.5/weather?q=san felipe,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 33
# City: Luderitz. http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 34
# City: Bredasdorp. http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 35
# City: Vaini. http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 36
# City: Churapcha. http://api.openweathermap.org/data/2.5/weather?q=churapcha,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 37
# City: Bonavista. http://api.openweathermap.org/data/2.5/weather?q=bonavista,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 38
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bluff. http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 39
# City: Souillac. http://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 40
# City: Kununurra. http://api.openweathermap.org/data/2.5/weather?q=kununurra,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 41
# City: Talcahuano. http://api.openweathermap.org/data/2.5/weather?q=talcahuano,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 42
# City: Bredasdorp. http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hollins. http://api.openweathermap.org/data/2.5/weather?q=hollins,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 43
# City: Chokurdakh. http://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 44
# City: Karema. http://api.openweathermap.org/data/2.5/weather?q=karema,tz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 45
# City: Puerto Colombia. http://api.openweathermap.org/data/2.5/weather?q=puerto colombia,co&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 46
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Harbour Breton. http://api.openweathermap.org/data/2.5/weather?q=harbour breton,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 47
# City: Tuktoyaktuk. http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 48
# City: Ruidoso. http://api.openweathermap.org/data/2.5/weather?q=ruidoso,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 49
# City: Twentynine Palms. http://api.openweathermap.org/data/2.5/weather?q=twentynine palms,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 50
# City: Cherskiy. http://api.openweathermap.org/data/2.5/weather?q=cherskiy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 51
# City: Barrow. http://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 52
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 53
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Alfred. http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 54
# City: Arraial do Cabo. http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 55
# City: Yellowknife. http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 56
# City: Roma. http://api.openweathermap.org/data/2.5/weather?q=roma,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 57
# City: Manali. http://api.openweathermap.org/data/2.5/weather?q=manali,in&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 58
# City: Sola. http://api.openweathermap.org/data/2.5/weather?q=sola,vu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 59
# City: Bluff. http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Souillac. http://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ambilobe. http://api.openweathermap.org/data/2.5/weather?q=ambilobe,mg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 60
# City: Bluff. http://api.openweathermap.org/data/2.5/weather?q=bluff,nz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Thurso. http://api.openweathermap.org/data/2.5/weather?q=thurso,gb&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 61
# City: Rocha. http://api.openweathermap.org/data/2.5/weather?q=rocha,uy&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 62
# City: Salinopolis. http://api.openweathermap.org/data/2.5/weather?q=salinopolis,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 63
# City: Severo-Kurilsk. http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 64
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Tuatapere. http://api.openweathermap.org/data/2.5/weather?q=tuatapere,nz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 65
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 66
# City: Nikolskoye. http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 67
# City: Longyearbyen. http://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 68
# City: Coihaique. http://api.openweathermap.org/data/2.5/weather?q=coihaique,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 69
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Enshi. http://api.openweathermap.org/data/2.5/weather?q=enshi,cn&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 70
# City: Hobart. http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 71
# City: Hithadhoo. http://api.openweathermap.org/data/2.5/weather?q=hithadhoo,mv&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Westport. http://api.openweathermap.org/data/2.5/weather?q=westport,nz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 72
# City: Souillac. http://api.openweathermap.org/data/2.5/weather?q=souillac,mu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 73
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Manbij. http://api.openweathermap.org/data/2.5/weather?q=manbij,sy&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 74
# City: Port Blair. http://api.openweathermap.org/data/2.5/weather?q=port blair,in&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 75
# City: Namatanai. http://api.openweathermap.org/data/2.5/weather?q=namatanai,pg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 76
# City: Abu Kamal. http://api.openweathermap.org/data/2.5/weather?q=abu kamal,sy&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 77
# City: Loreto. http://api.openweathermap.org/data/2.5/weather?q=loreto,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 78
# City: Voivodeni. http://api.openweathermap.org/data/2.5/weather?q=voivodeni,ro&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 79
# City: Luau. http://api.openweathermap.org/data/2.5/weather?q=luau,ao&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 80
# City: Znamenskoye. http://api.openweathermap.org/data/2.5/weather?q=znamenskoye,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 81
# City: Port Elizabeth. http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 82
# City: Klaksvik. http://api.openweathermap.org/data/2.5/weather?q=klaksvik,fo&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 83
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Antofagasta. http://api.openweathermap.org/data/2.5/weather?q=antofagasta,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 84
# City: Puerto Escondido. http://api.openweathermap.org/data/2.5/weather?q=puerto escondido,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 85
# City: Puerto Escondido. http://api.openweathermap.org/data/2.5/weather?q=puerto escondido,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Pevek. http://api.openweathermap.org/data/2.5/weather?q=pevek,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 86
# City: Bow Island. http://api.openweathermap.org/data/2.5/weather?q=bow island,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 87
# City: Srednekolymsk. http://api.openweathermap.org/data/2.5/weather?q=srednekolymsk,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 88
# City: Cape Town. http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Petropavlovsk-Kamchatskiy. http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 89
# City: Vaini. http://api.openweathermap.org/data/2.5/weather?q=vaini,to&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Gualeguaychu. http://api.openweathermap.org/data/2.5/weather?q=gualeguaychu,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 90
# City: Hamilton. http://api.openweathermap.org/data/2.5/weather?q=hamilton,bm&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 91
# City: Barrow. http://api.openweathermap.org/data/2.5/weather?q=barrow,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Vryburg. http://api.openweathermap.org/data/2.5/weather?q=vryburg,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 92
# City: Hobart. http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Saskylakh. http://api.openweathermap.org/data/2.5/weather?q=saskylakh,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 93
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bulle. http://api.openweathermap.org/data/2.5/weather?q=bulle,ch&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 94
# City: Provideniya. http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Matadi. http://api.openweathermap.org/data/2.5/weather?q=matadi,cd&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 95
# City: Ribeira Grande. http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 96
# City: San Patricio. http://api.openweathermap.org/data/2.5/weather?q=san patricio,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 97
# City: Scarborough. http://api.openweathermap.org/data/2.5/weather?q=scarborough,gb&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 98
# City: Lubao. http://api.openweathermap.org/data/2.5/weather?q=lubao,cd&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 99
# City: Avarua. http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 100
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Atasu. http://api.openweathermap.org/data/2.5/weather?q=atasu,kz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 101
# City: Concordia. http://api.openweathermap.org/data/2.5/weather?q=concordia,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 102
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Avarua. http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Les Cayes. http://api.openweathermap.org/data/2.5/weather?q=les cayes,ht&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 103
# City: Cockburn Town. http://api.openweathermap.org/data/2.5/weather?q=cockburn town,tc&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 104
# City: Alekseyevka. http://api.openweathermap.org/data/2.5/weather?q=alekseyevka,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 105
# City: Kota Belud. http://api.openweathermap.org/data/2.5/weather?q=kota belud,my&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 106
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Alfred. http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Praia da Vitoria. http://api.openweathermap.org/data/2.5/weather?q=praia da vitoria,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 107
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Strezhevoy. http://api.openweathermap.org/data/2.5/weather?q=strezhevoy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 108
# City: Chokurdakh. http://api.openweathermap.org/data/2.5/weather?q=chokurdakh,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Papar. http://api.openweathermap.org/data/2.5/weather?q=papar,my&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 109
# City: Upata. http://api.openweathermap.org/data/2.5/weather?q=upata,ve&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 110
# City: Hobart. http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Mar del Plata. http://api.openweathermap.org/data/2.5/weather?q=mar del plata,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 111
# City: Castro. http://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 112
# City: Farafangana. http://api.openweathermap.org/data/2.5/weather?q=farafangana,mg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 113
# City: Tasiilaq. http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 114
# City: College. http://api.openweathermap.org/data/2.5/weather?q=college,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 115
# City: Rio Gallegos. http://api.openweathermap.org/data/2.5/weather?q=rio gallegos,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 116
# City: Poum. http://api.openweathermap.org/data/2.5/weather?q=poum,nc&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 117
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Leningradskiy. http://api.openweathermap.org/data/2.5/weather?q=leningradskiy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 118
# City: Norman Wells. http://api.openweathermap.org/data/2.5/weather?q=norman wells,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 119
# City: Georgetown. http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 120
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Le Port. http://api.openweathermap.org/data/2.5/weather?q=le port,re&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 121
# City: Avarua. http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Saint-Philippe. http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 122
# City: Busselton. http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Lucapa. http://api.openweathermap.org/data/2.5/weather?q=lucapa,ao&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 123
# City: Dhidhdhoo. http://api.openweathermap.org/data/2.5/weather?q=dhidhdhoo,mv&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 124
# City: Georgetown. http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: New Norfolk. http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Challans. http://api.openweathermap.org/data/2.5/weather?q=challans,fr&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 125
# City: Kavieng. http://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Cabo San Lucas. http://api.openweathermap.org/data/2.5/weather?q=cabo san lucas,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 126
# City: Dikson. http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 127
# City: Port-Gentil. http://api.openweathermap.org/data/2.5/weather?q=port-gentil,ga&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 128
# City: Severo-Kurilsk. http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Cerqueira Cesar. http://api.openweathermap.org/data/2.5/weather?q=cerqueira cesar,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 129
# City: Thompson. http://api.openweathermap.org/data/2.5/weather?q=thompson,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 130
# City: Butaritari. http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 131
# City: Cidreira. http://api.openweathermap.org/data/2.5/weather?q=cidreira,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Alfred. http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bredasdorp. http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Yellowknife. http://api.openweathermap.org/data/2.5/weather?q=yellowknife,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Lieksa. http://api.openweathermap.org/data/2.5/weather?q=lieksa,fi&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 132
# City: Strumica. http://api.openweathermap.org/data/2.5/weather?q=strumica,mk&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 133
# City: Hermanus. http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 134
# City: Berlevag. http://api.openweathermap.org/data/2.5/weather?q=berlevag,no&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 135
# City: Nouadhibou. http://api.openweathermap.org/data/2.5/weather?q=nouadhibou,mr&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 136
# City: Angoram. http://api.openweathermap.org/data/2.5/weather?q=angoram,pg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 137
# City: Ikungi. http://api.openweathermap.org/data/2.5/weather?q=ikungi,tz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 138
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Leningradskiy. http://api.openweathermap.org/data/2.5/weather?q=leningradskiy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Baturaja. http://api.openweathermap.org/data/2.5/weather?q=baturaja,id&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 139
# City: Arraial do Cabo. http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Thompson. http://api.openweathermap.org/data/2.5/weather?q=thompson,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Alfred. http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Alfred. http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Yar-Sale. http://api.openweathermap.org/data/2.5/weather?q=yar-sale,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 140
# City: Lodja. http://api.openweathermap.org/data/2.5/weather?q=lodja,cd&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 141
# City: Busselton. http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ribeira Grande. http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Aguas Belas. http://api.openweathermap.org/data/2.5/weather?q=aguas belas,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 142
# City: Youghal. http://api.openweathermap.org/data/2.5/weather?q=youghal,ie&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 143
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Butaritari. http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Butaritari. http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bilibino. http://api.openweathermap.org/data/2.5/weather?q=bilibino,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 144
# City: Bulgan. http://api.openweathermap.org/data/2.5/weather?q=bulgan,mn&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 145
# City: Livingston. http://api.openweathermap.org/data/2.5/weather?q=livingston,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 146
# City: Fonte Boa. http://api.openweathermap.org/data/2.5/weather?q=fonte boa,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 147
# City: Ponta do Sol. http://api.openweathermap.org/data/2.5/weather?q=ponta do sol,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Elizabeth. http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Taoudenni. http://api.openweathermap.org/data/2.5/weather?q=taoudenni,ml&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 148
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Gorontalo. http://api.openweathermap.org/data/2.5/weather?q=gorontalo,id&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 149
# City: Port Alfred. http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bambous Virieux. http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 150
# City: Hamilton. http://api.openweathermap.org/data/2.5/weather?q=hamilton,bm&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Batagay-Alyta. http://api.openweathermap.org/data/2.5/weather?q=batagay-alyta,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 151
# City: Provideniya. http://api.openweathermap.org/data/2.5/weather?q=provideniya,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: San Patricio. http://api.openweathermap.org/data/2.5/weather?q=san patricio,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Butaritari. http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Khatanga. http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 152
# City: Port-Gentil. http://api.openweathermap.org/data/2.5/weather?q=port-gentil,ga&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Xinzhou. http://api.openweathermap.org/data/2.5/weather?q=xinzhou,cn&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 153
# City: Hobyo. http://api.openweathermap.org/data/2.5/weather?q=hobyo,so&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 154
# City: La Rioja. http://api.openweathermap.org/data/2.5/weather?q=la rioja,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 155
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Khatanga. http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Tuktoyaktuk. http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Usinsk. http://api.openweathermap.org/data/2.5/weather?q=usinsk,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 156
# City: Erenhot. http://api.openweathermap.org/data/2.5/weather?q=erenhot,cn&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 157
# City: Xochihuehuetlan. http://api.openweathermap.org/data/2.5/weather?q=xochihuehuetlan,mx&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 158
# City: Voi. http://api.openweathermap.org/data/2.5/weather?q=voi,ke&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 159
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ponta do Sol. http://api.openweathermap.org/data/2.5/weather?q=ponta do sol,cv&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hasaki. http://api.openweathermap.org/data/2.5/weather?q=hasaki,jp&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 160
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Elizabeth. http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Khatanga. http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kyra. http://api.openweathermap.org/data/2.5/weather?q=kyra,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 161
# City: Ribeira Grande. http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Busselton. http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Saint-Philippe. http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Butaritari. http://api.openweathermap.org/data/2.5/weather?q=butaritari,ki&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hobart. http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Luderitz. http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Babayurt. http://api.openweathermap.org/data/2.5/weather?q=babayurt,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 162
# City: Hermanus. http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: East London. http://api.openweathermap.org/data/2.5/weather?q=east london,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 163
# City: Agadir. http://api.openweathermap.org/data/2.5/weather?q=agadir,ma&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 164
# City: Casalmaggiore. http://api.openweathermap.org/data/2.5/weather?q=casalmaggiore,it&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 165
# City: Mahebourg. http://api.openweathermap.org/data/2.5/weather?q=mahebourg,mu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 166
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Touros. http://api.openweathermap.org/data/2.5/weather?q=touros,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 167
# City: Dikson. http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Georgetown. http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Tagusao. http://api.openweathermap.org/data/2.5/weather?q=tagusao,ph&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 168
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Juneau. http://api.openweathermap.org/data/2.5/weather?q=juneau,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 169
# City: Nikolskoye. http://api.openweathermap.org/data/2.5/weather?q=nikolskoye,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Georgetown. http://api.openweathermap.org/data/2.5/weather?q=georgetown,sh&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Vardo. http://api.openweathermap.org/data/2.5/weather?q=vardo,no&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 170
# City: Castro. http://api.openweathermap.org/data/2.5/weather?q=castro,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kulhudhuffushi. http://api.openweathermap.org/data/2.5/weather?q=kulhudhuffushi,mv&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 171
# City: Cape Town. http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hobart. http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bredasdorp. http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Myaundzha. http://api.openweathermap.org/data/2.5/weather?q=myaundzha,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 172
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Carnarvon. http://api.openweathermap.org/data/2.5/weather?q=carnarvon,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 173
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kloulklubed. http://api.openweathermap.org/data/2.5/weather?q=kloulklubed,pw&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 174
# City: Matagami. http://api.openweathermap.org/data/2.5/weather?q=matagami,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 175
# City: Concordia. http://api.openweathermap.org/data/2.5/weather?q=concordia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ribeira Grande. http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Esperance. http://api.openweathermap.org/data/2.5/weather?q=esperance,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 176
# City: Jamestown. http://api.openweathermap.org/data/2.5/weather?q=jamestown,sh&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# ...
# Status code: 200. DF length is now: 469
# City: Lavrentiya. http://api.openweathermap.org/data/2.5/weather?q=lavrentiya,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Chagoda. http://api.openweathermap.org/data/2.5/weather?q=chagoda,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 470
# City: Brae. http://api.openweathermap.org/data/2.5/weather?q=brae,gb&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 471
# City: Sao Desiderio. http://api.openweathermap.org/data/2.5/weather?q=sao desiderio,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 472
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Norden. http://api.openweathermap.org/data/2.5/weather?q=norden,de&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 473
# City: Ambon. http://api.openweathermap.org/data/2.5/weather?q=ambon,id&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 474
# City: Bogense. http://api.openweathermap.org/data/2.5/weather?q=bogense,dk&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 475
# City: Santa Cruz. http://api.openweathermap.org/data/2.5/weather?q=santa cruz,cr&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 476
# City: Fare. http://api.openweathermap.org/data/2.5/weather?q=fare,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 477
# City: Kaoma. http://api.openweathermap.org/data/2.5/weather?q=kaoma,zm&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 478
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Husavik. http://api.openweathermap.org/data/2.5/weather?q=husavik,is&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Saint-Philippe. http://api.openweathermap.org/data/2.5/weather?q=saint-philippe,re&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Turiacu. http://api.openweathermap.org/data/2.5/weather?q=turiacu,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 479
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Fortuna. http://api.openweathermap.org/data/2.5/weather?q=fortuna,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Lundazi. http://api.openweathermap.org/data/2.5/weather?q=lundazi,zm&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 480
# City: Khatanga. http://api.openweathermap.org/data/2.5/weather?q=khatanga,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Vuktyl. http://api.openweathermap.org/data/2.5/weather?q=vuktyl,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Punta Arenas. http://api.openweathermap.org/data/2.5/weather?q=punta arenas,cl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Thompson. http://api.openweathermap.org/data/2.5/weather?q=thompson,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Piacabucu. http://api.openweathermap.org/data/2.5/weather?q=piacabucu,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Touros. http://api.openweathermap.org/data/2.5/weather?q=touros,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bethel. http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Fortuna. http://api.openweathermap.org/data/2.5/weather?q=fortuna,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bredasdorp. http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Qaanaaq. http://api.openweathermap.org/data/2.5/weather?q=qaanaaq,gl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Alfred. http://api.openweathermap.org/data/2.5/weather?q=port alfred,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: East London. http://api.openweathermap.org/data/2.5/weather?q=east london,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Christchurch. http://api.openweathermap.org/data/2.5/weather?q=christchurch,nz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 481
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Rikitea. http://api.openweathermap.org/data/2.5/weather?q=rikitea,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Petropavlovsk-Kamchatskiy. http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Alofi. http://api.openweathermap.org/data/2.5/weather?q=alofi,nu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Odesskoye. http://api.openweathermap.org/data/2.5/weather?q=odesskoye,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 482
# City: Ushuaia. http://api.openweathermap.org/data/2.5/weather?q=ushuaia,ar&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Longyearbyen. http://api.openweathermap.org/data/2.5/weather?q=longyearbyen,sj&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Matara. http://api.openweathermap.org/data/2.5/weather?q=matara,lk&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 483
# City: La Asuncion. http://api.openweathermap.org/data/2.5/weather?q=la asuncion,ve&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 484
# City: Iqaluit. http://api.openweathermap.org/data/2.5/weather?q=iqaluit,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Camacha. http://api.openweathermap.org/data/2.5/weather?q=camacha,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bilibino. http://api.openweathermap.org/data/2.5/weather?q=bilibino,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kaupanger. http://api.openweathermap.org/data/2.5/weather?q=kaupanger,no&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 485
# City: Saint George. http://api.openweathermap.org/data/2.5/weather?q=saint george,bm&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Katherine. http://api.openweathermap.org/data/2.5/weather?q=katherine,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bethel. http://api.openweathermap.org/data/2.5/weather?q=bethel,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Obo. http://api.openweathermap.org/data/2.5/weather?q=obo,cf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 486
# City: Ribeira Grande. http://api.openweathermap.org/data/2.5/weather?q=ribeira grande,pt&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Avarua. http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Chuy. http://api.openweathermap.org/data/2.5/weather?q=chuy,uy&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Banjarmasin. http://api.openweathermap.org/data/2.5/weather?q=banjarmasin,id&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 487
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Leh. http://api.openweathermap.org/data/2.5/weather?q=leh,in&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 488
# City: Busselton. http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Geraldton. http://api.openweathermap.org/data/2.5/weather?q=geraldton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Esperance. http://api.openweathermap.org/data/2.5/weather?q=esperance,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Komsomolskiy. http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hermanus. http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Port Lincoln. http://api.openweathermap.org/data/2.5/weather?q=port lincoln,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 489
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kavieng. http://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bejar. http://api.openweathermap.org/data/2.5/weather?q=bejar,es&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 490
# City: Udarnyy. http://api.openweathermap.org/data/2.5/weather?q=udarnyy,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 491
# City: Aklavik. http://api.openweathermap.org/data/2.5/weather?q=aklavik,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: New Norfolk. http://api.openweathermap.org/data/2.5/weather?q=new norfolk,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Arraial do Cabo. http://api.openweathermap.org/data/2.5/weather?q=arraial do cabo,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Atuona. http://api.openweathermap.org/data/2.5/weather?q=atuona,pf&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Busselton. http://api.openweathermap.org/data/2.5/weather?q=busselton,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Dikson. http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Cape Town. http://api.openweathermap.org/data/2.5/weather?q=cape town,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Richards Bay. http://api.openweathermap.org/data/2.5/weather?q=richards bay,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 492
# City: Port Elizabeth. http://api.openweathermap.org/data/2.5/weather?q=port elizabeth,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Tuatapere. http://api.openweathermap.org/data/2.5/weather?q=tuatapere,nz&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Goulburn. http://api.openweathermap.org/data/2.5/weather?q=goulburn,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 493
# City: Caravelas. http://api.openweathermap.org/data/2.5/weather?q=caravelas,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 494
# City: Kovernino. http://api.openweathermap.org/data/2.5/weather?q=kovernino,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 495
# City: Kavieng. http://api.openweathermap.org/data/2.5/weather?q=kavieng,pg&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Puerto Ayora. http://api.openweathermap.org/data/2.5/weather?q=puerto ayora,ec&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Dikson. http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Albany. http://api.openweathermap.org/data/2.5/weather?q=albany,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kabelvag. http://api.openweathermap.org/data/2.5/weather?q=kabelvag,no&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 496
# City: Pevek. http://api.openweathermap.org/data/2.5/weather?q=pevek,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Paracuru. http://api.openweathermap.org/data/2.5/weather?q=paracuru,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 497
# City: Salinas. http://api.openweathermap.org/data/2.5/weather?q=salinas,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Tuktoyaktuk. http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk,ca&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hobart. http://api.openweathermap.org/data/2.5/weather?q=hobart,au&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Tiksi. http://api.openweathermap.org/data/2.5/weather?q=tiksi,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Sorland. http://api.openweathermap.org/data/2.5/weather?q=sorland,no&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 498
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Santa Fe. http://api.openweathermap.org/data/2.5/weather?q=santa fe,cu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 499
# City: Luderitz. http://api.openweathermap.org/data/2.5/weather?q=luderitz,na&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Kapaa. http://api.openweathermap.org/data/2.5/weather?q=kapaa,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Tasiilaq. http://api.openweathermap.org/data/2.5/weather?q=tasiilaq,gl&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hilo. http://api.openweathermap.org/data/2.5/weather?q=hilo,us&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bredasdorp. http://api.openweathermap.org/data/2.5/weather?q=bredasdorp,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Avarua. http://api.openweathermap.org/data/2.5/weather?q=avarua,ck&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Luanda. http://api.openweathermap.org/data/2.5/weather?q=luanda,ao&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Bambous Virieux. http://api.openweathermap.org/data/2.5/weather?q=bambous virieux,mu&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Dikson. http://api.openweathermap.org/data/2.5/weather?q=dikson,ru&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Touros. http://api.openweathermap.org/data/2.5/weather?q=touros,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Sao Joao da Barra. http://api.openweathermap.org/data/2.5/weather?q=sao joao da barra,br&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Hermanus. http://api.openweathermap.org/data/2.5/weather?q=hermanus,za&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# City: Sandwick. http://api.openweathermap.org/data/2.5/weather?q=sandwick,gb&units=imperial&APPID=e7f10d5a16922e4cea2f8de06a28314a
# Status code: 200. DF length is now: 500
#      city_name country_code Latitude Longitude Temp (F) Humidity (%)  \
# 0         hilo           us    19.71   -155.08    73.04           70
# 1       faanui           pf   -16.48   -151.75     84.1           98
# 2         chuy           uy   -33.69    -53.46    75.46           94
# 3  provideniya           ru    64.42   -173.23     19.4           57
# 4      ushuaia           ar   -54.81    -68.31       41           80
#
#   Cloudiness (%) Wind Speed (mph)
# 0             75            11.41
# 1             88            19.82
# 2             64              6.4
# 3             75             17.9
# 4             40             5.82

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
sns.regplot(x="Latitude", y="Temp (F)", data=cities_df, fit_reg=False).set_title('Temp (F) by Latitude')


plt.savefig("graphs/Temp (F) by Latitude.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
sns.regplot(x="Latitude", y="Humidity (%)", data=cities_df, fit_reg=False).set_title('Humidity (%) by Latitude')


plt.savefig("graphs/Humidity (%) by Latitude.png")

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
sns.regplot(x="Latitude", y="Cloudiness (%)", data=cities_df, fit_reg=False).set_title('Cloud Cover (%) by Latitude')

plt.savefig("graphs/Cloud Cover (%) by Latitude.png")

plt.show()

# %% [raw]
# #### Latitude vs. Wind Speed Plot

# %%
 sns.regplot(x="Latitude", y="Wind Speed (mph)", data=cities_df, fit_reg=False).set_title('Wind Speed (mph) by Latitude')

plt.savefig("graphs/Wind Speed (mph) by Latitude.png")

plt.show()
